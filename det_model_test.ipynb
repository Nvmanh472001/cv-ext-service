# %%
import torch
from model.det_model.detection_model import DetectionModel

config = {
    'Backbone': {'scale': 0.5, 'disable_se': True},
    'Neck': {'out_channels': 96, 'use_residual': True},
    'Head': {'k': 50}
}

# %%
model = DetectionModel(config)

# %%
weights_path = "model/checkpoints/en_ptocr_v3_det_infer.pth"
model.load_state_dict(torch.load(weights_path))
# Out:
# <All keys matched successfully>

# %%
## With yaml file:
from model.tools.infer.utility import read_cfg_from_yaml

yaml_path = 'model/configs/det_cfg.yml'
nnetwork_cfg = read_cfg_from_yaml(yaml_path, cfg_op='net')

nnetwork_cfg
# Out:
# {'Backbone': {'scale': 0.5, 'disable_se': True},
#  'Neck': {'out_channels': 96, 'use_residual': True},
#  'Head': {'k': 50}}

# %%
model_from_yarm = DetectionModel(nnetwork_cfg)

# %%
model_from_yarm.eval()
# Out:
# DetectionModel(
#   (backbone): MobileNetV3(
#     (conv): ConvBNLayer(
#       (conv): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): Activation(
#         (act): Hswish()
#       )
#     )
#     (stages): ModuleList(
#       (0): Sequential(
#         (0): ResidualUnit(
#           (expand_conv): ConvBNLayer(
#             (conv): Conv2d(8, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): Activation(
#               (act): ReLU(inplace=True)
#             )
#           )
#           (bottleneck_conv): ConvBNLayer(
#             (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
